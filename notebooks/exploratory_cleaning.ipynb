# %% [markdown]
# # Exploratory Data Check
#
# This notebook is intentionally lightweight. The production-ready cleaning logic lives in `src/rental_market_analysis/pipeline.py`, while this notebook is kept for quick inspection and ad hoc exploration.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.insert(0, str(PROJECT_ROOT / "src"))

from rental_market_analysis.pipeline import build_combined_dataset

# %%
dataset = build_combined_dataset({
    "Zurich": PROJECT_ROOT / "data" / "raw" / "zurich_listings.csv",
    "Milan": PROJECT_ROOT / "data" / "raw" / "milan_listings.csv",
})

dataset.head()

# %%
dataset.groupby("city")[["price", "reviews_per_month", "availability_365"]].agg(["mean", "median"]).round(2)
